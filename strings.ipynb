# %%
str="sameera"
print(str)
# Out:
# sameera

# %%
str="sameeda"
rev=str[::-1]
print(rev)
# Out:
# adeemas

# %%
s="madam"
rev=s[::-1]
if s in rev:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
s=[1,2,3,4,5,6]
index=s[1:6]
print(index)
# Out:
# [2, 3, 4, 5, 6]
