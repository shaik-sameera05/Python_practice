# %%
str="sameera"
print(str)
# Out:
# sameera

# %%
name="sasikumar"
city="hyderabad"
print(name)
print(city)
# Out:
# sasikumar
# hyderabad

# %%
str="sameeda"
rev=str[::-1]
print(rev)
# Out:
# adeemas

# %%
s="madam"
rev=s[::-1]
if s in rev:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
s=[1,2,3,4,5,6]
index=s[1:6]
print(index)
# Out:
# [2, 3, 4, 5, 6]

# %%
#indexing
name="sameera shaik"
print(name[0])  # Output: s
print(name[1])  # Output: a
print(name[2])  # Output: m
print(name[3])  # Output: e
print(name[4])  # Output: e
print(name[5])  # Output: r
print(name[6])  # Output: a
print(name[7])  # Output:  
print(name[8])  # Output: s
print(name[9])  # Output: h
print(name[10]) # Output: a
print(name[11]) # Output: i
print(name[12]) # Output: k
# Out:
# s
# a
# m
# e
# e
# r
# a
#
# s
# h
# a
# i
# k

# %%
name="sasikumar"
print(name[-1])  # Output: r
print(name[-2])  # Output: m
print(name[-3])  # Output: u
print(name[-4])  # Output: a
print(name[-5])  # Output: r
# Out:
# r
# a
# m
# u
# k

# %%
#string slicing
name="sasikumar"
print(name[0:5])  # Output: sasik
print(name[5:9]) # Output: umar
# Out:
# sasik
# umar

# %%
name="sameera"
print(name[1:5])  # Output: amee
print(name[0:7:2]) # Output: smea
print(name[1:5])   # ame e
print(name[:4])    # Same
print(name[2:])    # meera
print(name[:])     # Sameera
# Out:
# amee
# smea
# amee
# same
# meera
# sameera

# %%
#string length
name="sameera"
print(len(name))
# Out:
# 7

# %%
##string methods

name="sameera"
print(name.upper())  # Output: SAMEERA
print(name.lower())  # Output: sameera
print(name.capitalize())  # Output: Sameera
print(name.title())  # Output: Sameera
print(name.swapcase())  # Output: SAMEERA
# Out:
# SAMEERA
# sameera
# Sameera
# Sameera
# SAMEERA

# %%
#strip
name="  sameera  "
print(name.strip())  # Output: sameera
print(name.lstrip()) # Output: sameera
print(name.rstrip()) # Output:  sameera
# Out:
# sameera
# sameera
#   sameera

# %%
#strip
name="  sameera  "
print(name.strip())  # Output: sameera
print(name.lstrip()) # Output: sameera
print(name.rstrip()) # Output:  sameera
# Out:
# sameera
# sameera
#   sameera

# %%
#strip
name="  sameera  "
print(name.strip())  # Output: sameera
print(name.lstrip()) # Output: sameera
print(name.rstrip()) # Output:  sameera
# Out:
# sameera
# sameera
#   sameera

# %%
##string methods

name="sameera"
print(name.upper())  # Output: SAMEERA
print(name.lower())  # Output: sameera
print(name.capitalize())  # Output: Sameera
print(name.title())  # Output: Sameera
print(name.swapcase())  # Output: SAMEERA

# %%
##string methods

name="sameera"
print(name.upper())  # Output: SAMEERA
print(name.lower())  # Output: sameera
print(name.capitalize())  # Output: Sameera
print(name.title())  # Output: Sameera
print(name.swapcase())  # Output: SAMEERA

# %%
text="sameera"
print(text.replace("s","S"))  # Output: Sameera
# Out:
# Sameera

# %%
text="samera"
print(len(text)-1)
# Out:
# 5

# %%
#accessing characters in a string
name="sameera"
print(name[0])  # Output: s
print(name[1])  # Output: a
index=3
print(name[index])  # Output: e
# Out:
# s
# a
# e

# %%
name="yasmeen"
name="x"+name[1:]
print(name)  # Output: xasmeen
# Out:
# xasmeen

# %%
#string concatenation
first_name="sameera"
second_name="shaik"
full_name=first_name+" "+second_name 
print(full_name)  # Output: sameera shaik
# Out:
# sameera shaik

# %%
#string repittion
name="sameera"  
print(name * 3) 
print("*"*10) # Output: **********
# Out:
# sameerasameerasameera
# **********

# %%
#step in sclicing
name="sameera"
name[0:7:2]  # Output: smea
# Out:
# 'smea'

# %%
#reversing a string
name="sameera"
reversed_name=name[::-1]
print(reversed_name)  # Output: aremas
# Out:
# areemas

# %%
text = input("Enter a string: ")
print(text[0])
print(text[-1])
print(len(text))
print(text[::-1])
# Out:
# s
# n
# 7
# nirbahs

# %%
text="sameera"
vowels = "aeiouAEIOU"
count=0
for char in text:
    if char in vowels:
        count += 1
        print(char)
print("Number of vowels:", count)
# Out:
# a
# e
# e
# a
# Number of vowels: 4

# %%
text="sameera"
vowels = "aeiouAEIOU"
count=0
for char in text:
    if char.isalpha() and char not in vowels:
        count += 1
        print(char)
print("Number of consonants:", count)
# Out:
# s
# m
# r
# Number of consonants: 3

# %%
#counting vowels and consonants in a string
text = "Hello World"
vowels = "aeiouAEIOU"
vowel_count = 0
consonant_count = 0

for char in text:
    if char.isalpha():
        if char in vowels:
            vowel_count += 1
        else:
            consonant_count += 1

print("Number of vowels:", vowel_count)
print("Number of consonants:", consonant_count)
# Out:
# Number of vowels: 3
# Number of consonants: 7

# %%
#reversing a string using a loop
text = "Hello World"
reversed_text = ""
for char in text:
    reversed_text = char + reversed_text
print("Original string:", text)
print("Reversed string:", reversed_text)
# Out:
# Original string: Hello World
# Reversed string: dlroW olleH

# %%
text = "programming"
char="g"
count=0
for c in text:
    if c == char:
        count += 1  
print(count)
# Out:
# 2

# %%
text = "python12345"
count=0
for char in text:
    if char.isdigit():
        count += 1
print("Number of digits:", count)
# Out:
# Number of digits: 5

# %%
text="sameera"
reversed_text = text[::-1]
if text == reversed_text:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# not palindrome

# %%
#string formatting
name="sameera"
print(f"Hello, {name}!")
# Out:
# Hello, sameera!

# %%
#string relplication
name="sameera"
print(name * 3)
# Out:
# sameerasameerasameera

# %%
#string formatting old method
#using %
name="sameera"
age=25
print("my name is %s and my age is %d"%(name,age))
# Out:
# my name is sameera and my age is 25

# %%
#.format method
name="sameera"
age=25
city="hyderabad"
print("my name is {} and my age is {} and my city is {}".format(name,age,city))
# Out:
# my name is sameera and my age is 25 and my city is hyderabad

# %%
#positional formatting
name="sameera"
age=25
city="hyderabad"
print("my age is {1} and my name is {0} and my city is {2}".format(name,age,city))
# Out:
# my age is 25 and my name is sameera and my city is hyderabad

# %%
#key formatting
name="sameera"
age=25
city="hyderabad"
print("my name is {n} and my age is {a} and my city is {c}".format(n=name,a=age,c=city))
# Out:
# my name is sameera and my age is 25 and my city is hyderabad

# %%
#f-strings
name = "Sameera"
age = 21
print(f"my name is {name} and my age is {age}")
# Out:
# my name is Sameera and my age is 21

# %%
a=10
b=20
print(f"sum= {a+b}")
# Out:
# sum= 30

# %%
college="mother theresa institute of engineering and technology"
print(f"{college.upper()}")
# Out:
# MOTHER THERESA INSTITUTE OF ENGINEERING AND TECHNOLOGY

# %%
price = 125.6789
print(f"{price:.2f}")
# Out:
# 125.68

# %%
#string camparision
print("apple"=="apple")
print("apple"=="Apple")
print("apple"<"banana")
print("cat" > "car")
print("hello" != "Hello")
# Out:
# True
# False
# True
# True
# True

# %%
text1 = "listen"
text2 = "silent"
print(text1==text2)
# Out:
# False

# %%
text1 = "listen"
text2 = "silent"

if sorted(text1) == sorted(text2):
    print("Anagram")
else:
    print("Not anagram")
# Out:
# Anagram

# %%
t1="goes"
t2="eog"
if sorted(t1)==sorted(t2):
    print("anagram")
else:
    print("not anagram")
# Out:
# not anagram
