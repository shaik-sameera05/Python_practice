# %%
class Student:
    pass

s1 = Student()
s2 = Student()

print(s1)
print(s2)

# %%
class student:
    pass

# %%
class Student:

    def __init__(self):
        print("Student object created")


s1 = Student()
s2 = Student()
# Out:
# Student object created
# Student object created
