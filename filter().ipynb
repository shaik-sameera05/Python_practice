# %%
lst=[10,13,18,15,20]
def fun(x):
    return x%2==0
res=list(filter(fun,lst))
print(res)
# Out:
# [10, 18, 20]

# %%
#using lambda function
lst=[10,13,18,15,20]
res=list(filter(lambda x:x%2==0,lst))
print(res)
# Out:
# [10, 18, 20]
