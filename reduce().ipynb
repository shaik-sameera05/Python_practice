# %%
#using lambda function
from functools import reduce
lst=[1,2,3,4,5]
res=reduce(lambda x,y:x+y,lst)
print(res)
# Out:
# 15

# %%
from functools import reduce
lst=[1,2,3,4,5]
def fun(x,y):
    return x+y
res=reduce(fun,lst)
print(res)
# Out:
# 15
