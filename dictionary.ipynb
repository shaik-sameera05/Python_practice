# %%
#dictionary
student = {
    "name": "Sameera",
    "age": 21,
    "branch": "CSE"
}

print(student)
# Out:
# {'name': 'Sameera', 'age': 21, 'branch': 'CSE'}

# %%
student = {
    "name": "Sameera",
    "age": 21,
    "branch": "CSE"
}

print(student["name"])
# Out:
# Sameera

# %%
student = {
    "name": "Sameera",
    "age": 21
}

student["branch"] = "CSE"

print(student)
# Out:
# {'name': 'Sameera', 'age': 21, 'branch': 'CSE'}
