# %%
def greet():
    print("hello")
greet()
# Out:
# hello

# %%
def add (a,b):
    print(a+b)
add(10,20)
# Out:
# 30

# %%
def greet(name):
    print("hello",name)
greet("shaik sameera")
# Out:
# hello shaik sameera

# %%
def add(a,b):
    return a+b
result=add(10,20)
print(result)
# Out:
# 30

# %%
def greet(n):
    return n*n
print(greet(5))
print(greet(10))
# Out:
# 25
# 100

# %%
def name(name="python"):
    print("hello",name)
name("shaik sameera")
name()
# Out:
# hello shaik sameera
# hello python

# %%
def power(num,exponent=2):
    return num**exponent
print(power(5))
print(power(5,3))
# Out:
# 25
# 125

# %%
def large(a,b):
    if a>b:
        return a
    else:
        return b
print(large(10,20))
# Out:
# 20

# %%
def largest(a,b,c):
    if a>b and a>c:
        return a
    elif b>a and b>c:
        return b
        return c
print(largest(10,70,30))
# Out:
# 70

# %%
def is_even(num):
    if num%2==0:
        return True
    else:
        return False
print(is_even(10)) 
print(is_even(11))
# Out:
# True
# False

# %%
def check(num):
    if num>0:
        return "positive"
    elif num<0:
        return "negative"
    else:
        return "zero"
print(check(10))
print(check(-10))
print(check(0))
# Out:
# positive
# negative
# zero

# %%
def leap_year(year):
    if year%4==0:
        if year%100==0:
            if year%400==0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False
print(leap_year(2020))
# Out:
# True

# %%
n=int(input("enter number"))
fact=1
for i in range(1,n+1):
    fact=fact*i
print(fact)
# Out:
# 24

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
     fact*=i
    return fact 
print(factorial(5))
# Out:
# 120

# %%
def factorial(n):
    fact = 1

    for i in range(1, n + 1):
        fact *= i

    return fact

print(factorial(5))

# %%
def add(*number):
    total=0
    for i in number:
        total+=i
    print(total)
add(10,20,30,40,)
add(1,2,3,4,5,6,7,8,9)
add(3,67,89,76,54)
# Out:
# 100
# 45
# 289

# %%
def add(name,*marks):
    print(name)
    print(marks)
add("sameera",10,35,60)
# Out:
# sameera
# (10, 35, 60)

# %%
def count_number(n):
    count = 0
    while n > 0:
        count += 1
        n //= 10
    return count
def main():
    n=int(input("enter number"))
    print(count_number(n))
if __name__ == "__main__":
    main()
# Out:
# 9

# %%
def factorial(n):
    res=1
    for i in range(1,n+1):
        res*=i
    return res
def main():
    n=int(input())
    print(factorial(n))
if __name__ =='__main__' :
    main()
# Out:
# 720

# %%
#without input&without return value
def mul():
    a=10
    b=20
    c=a*b
    print(c)
mul()
# Out:
# 200

# %%
#with input&without return value
def mul(a, b):
    c=a*b
    print(c)    
mul(10, 20)
# Out:
# 200

# %%
#with input&with return value
def mul(a, b):
    c=a*b
    return c
res=mul(10, 20)
print(res)
# Out:
# 200

# %%
#without input&with return value
def mul():
    a=10
    b=20
    c=a*b
    return c
res=mul()
print(res)
# Out:
# 200

# %%
#without input&with return value
def mul():
    a=10
    b=20
    c=a*b
    return c
res=mul()
print(res)
# Out:
# 200

# %%
def mul(a,b=3):
    c=a**b
    return c
res=mul(345,6)
print(res)
# Out:
# 1686221298140625

# %%
def pizza_toppings(topping):
    print(topping)
pizza_toppings("mushrooms")
# Out:
# mushrooms

# %%
def  add(a,b):
    c=a+b
    print(c)
add(a=199,b=356)
# Out:
# 555

# %%
def pizza_toppings(*topping):
    print(topping)
pizza_toppings('mushrooms','green peppers','extra cheese')
# Out:
# ('mushrooms', 'green peppers', 'extra cheese')

# %%
def pizza_toppings(**data):
    print(data) 
pizza_toppings(name="sam",age=23,ayg=60.5,gender="female")
# Out:
# {'name': 'sam', 'age': 23, 'ayg': 60.5, 'gender': 'female'}

# %%
def greet(name):
    print("hello sameera,",name)
greet("welcome!")
# Out:
# hello sameera, welcome!

# %%
def square(num):
    return num**2
square(5)
# Out:
# 25

# %%
def largest(a,b):
    if a>b:
        return a
    else:
        return b
largest(10,20)
# Out:
# 20

# %%
def even(num):
    if num%2==0:
        return True
    else:
        return False
even(4)
# Out:
# True

# %%
def add(a,b):
    c=a+b
    return c
add(10,20)
# Out:
# 30

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
factorial(5)
print(factorial(5))
# Out:
# 120

# %%
def prime(n):
    if n<=1:
        return False
    for i in range(2,n):
        if n%i==0:
            return False
    return True
prime(13)
# Out:
# True

# %%
def prime(n):
    if n<=1:
        return False
    for i in range(2,n):
        if n%i==1:
            return True
        else:
            return False
    return True
prime(13)
# Out:
# True

# %%
def reversed(S):
    return S[::-1]
reversed("hello")
print(reversed("hello"))
# Out:
# olleh

# %%
def count_vowels(n):
    count=0
    for i in n:
        if i in "aeiouAEIOU":
            count=count+1
    return count
count_vowels("shaiksameera")
# Out:
# 6

# %%
def palindrome(n):
    return n==n[::-1]
palindrome("jham")
# Out:
# False

# %%
def greet():
    print("python is awesome")
greet()
# Out:
# python is awesome

# %%
def mul(a,b):
    c=a+b
    print(c)
mul (a=10,b=20)
# Out:
# 30

# %%
def number(n):
    return n
number(100)
# Out:
# 100

# %%
def add(a,b):
    c=a+b
    return c
def sub(c,d):
    s=c-d
    return s
def mul(e,f):
    l=e*f
    return l
def div(g,h):
    p=g/h
    return p
a,b=map(int,input("Enter a two number:").split(","))
c,d=map(int,input("Enter a two number:").split(","))
e,f=map(int,input("Enter a two number:").split(",")) 
g,h=map(int,input("Enter a two number:").split(",")) 

print(add(a,b))
print(sub(c,d))
print(mul(e,f))
print(div(g,h))
# Out:
# 3
# -1
# 12
# 0.8

# %%
def second_largest(a,b,c):
    if a>b and a>c:
        return a
    elif b>a and b>c:
        return b
    else:
        return c 
print(second_largest(10,20,30))
# Out:
# 30

# %%
def add(a,b):
    c=a+b
    return c
def sub(c,d):
    s=c-d
    return s
def mul(e,f):
    l=e*f
    return l
def div(g,h):
    p=g/h
    return p 

print(add(10,20))
print(sub(30,10))
print(mul(5,6))
print(div(100,10))
# Out:
# 30
# 20
# 30
# 10.0
