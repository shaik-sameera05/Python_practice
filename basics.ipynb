# %%
print("hello")
# Out:
# hello

# %%
a=3
b=4
print("sum:",a+b)
# Out:
# sum: 7

# %%
n=47
if n % 2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
n=3
fact=1
for i in range(1,n+1):
    fact*=i
    print(fact)
# Out:
# 1
# 2
# 6

# %%
str="sameera"
print(str[::-1])
# Out:
# areemas

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s="madam"
if s==s[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
str=input("enter a string:")
count=0
for i in str:
    if i in "aeiou":
        count+=1
        print(count)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
s1={1,2,3}
s2={5,6,7}
s3=s1.union(s2)
print(s3)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
print("line1\n line2\n2")
# Out:
# line1
#  line2
# 2

# %%
age=int(input("enter age:"))
if age>18:
 print("eligible for vote")
else:
 print("not eligible")
# Out:
# not eligible

# %%
marks=int(input("enter marks"))
if (marks>90):
    print("distin")
elif (marks>86):
    print("frst clss")
elif(marks>56):
    print("second ")
else:
    print("fail")

# %%
list=[1,3,44,]
print(list)
print(type(list))
# Out:
# [1, 3, 44]
# <class 'list'>

# %%
#check the number even or odd
num=int(input("enter the number"))
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
#find largest number
a=7
b=8
if a>b:
    print(b)
else:
    print(a)
# Out:
# 7

# %%
#multiplication table
num=int(input("enter num"))
for i in range(1,11):
    print(num,"x",i,"=",num*i)
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
#count vowels
str=input("enter word")
count=0
if i in str: 
 for i in "aeiouAEIOU":
    count+=1
    print(count)

# %%
#count vowels
str=input("enter word:")
count=0
for i in str: 
    if i in "aeiouAEIOU":
      count+=1
print(count)
# Out:
# 4

# %%
num=int(input("enter num:"))
count=0
for i in range(1,num+1):
    if num%i==1:
        count+=1
if num==2:
    print ("prime")
else:
    print("not prime")
# Out:
# not prime

# %%
num=int(input("enter num:"))
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
n=int(input("enter e numner\n"))
for i in range(1,11):
    print(n,"x",i,"=",n*i)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
num=int(input("enter a  number:"))
if num>0:
    print("positive")
elif num==0:
    print("zero")
else:
    print("negative")
# Out:
# positive

# %%
num=int(input("enter number:"))
if num%2==0:
    print("even")
else:print("odd")
# Out:
# odd

# %%
str=input("enter text:")
count=0
for i in str:
 if i in("aeiouAEIOU"):
  count+=1
print(count)
# Out:
# 17

# %%
num=int(input("enter a number"))
fact=1
for i in range(1,num+1):
    fact=fact*i
print(fact)
# Out:
# 24

# %%
num=int(input("enter a number"))
sum=1
for i in range(1,num+1):
    sum=sum*i
print(sum)
# Out:
# 24

# %%
num=input("enter a number:")
print(num[::-1])
# Out:
# nohtyp

# %%
a=int(input("enter frst number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
if a>b and a>c:
    print(a)
elif b>c:
    print(b)
else:
    print(c)
# Out:
# 9

# %%
a=input("enter a str:")
rev=a[::-1]
if a in rev:
    print("palindrome")
else:
    print("not")
# Out:
# palindrome

# %%
a=100000000000545455
count=0
while a>0: 
    a=a//10
    count+=1
print(count)
# Out:
# 18

# %%
a=12387
count=0
while a>0:
    a=a//10
    count+=1
print(count)
# Out:
# 5

# %%
       

a=167890
largest=0
while a>0:
    digit=a%10
    if digit>largest:
        largest=digit
print(largest)

# %%
       

a=167890
largest=0
while a>0:
    digit=a%10
    if digit>largest:
        largest=digit
print(largest)

# %%
num=int(input("enter numer"))
even=0
odd=0
while num>0:
    digit=num%10
    if digit%2==0:
        even+=1
    else:
        odd+=1
    num=num//10 
print("count even:",even)
print("coutn odd:",odd)  
num=num//10
# Out:
# count even: 5
# coutn odd: 5

# %%
num=(input("enter numer"))
rev=num[::-1]
print(rev)
# Out:
# mas

# %%
str="education"
count_vowels=0
for i in str:
    if i in "aeiou":
     count_vowels+=1
print("num of vowels:",count_vowels)
# Out:
# num of vowels: 5

# %%
str="PyThOn"
upper=0
lower=0
for i in str:
    if  i.upper():
        upper+=1
    else:
        lower+=1
print("num of uppercase letters:",upper)
print("num of lowercase letters:",lower)
# Out:
# num of uppercase letters: 3
# num of lowercase letters: 3

# %%
str="I love python programming"
words=str.split()
print(len(words))
# Out:
# 4

# %%
str="I love python programming"
word=str.split()
largest=""
for i in words:
    if len(i)>len(largest):
        largest=i
print("largest word:",largest)
# Out:
# largest word: programming

# %%
s="i am shaik sameera"
word=s.split()
for i in word:
    if len(i)>len(largest):
        largest=i
print(largest)
# Out:
# programming

# %%
s="i am cse student"
word=s.split()
smallest=word[0]
for i in word:
    if len(i)<len(smallest):
        smallest=i
print(smallest)
# Out:
# i

# %%
s="madam"
rev=s[::-1]
if s==rev:
    print("palindrome")
else:
    print("not")
# Out:
# palindrome

# %%
num=int(input("enter numer"))
count=0
for i in range(2,num):
    if i%2==0:
        count+=1
if i==0:
    print("prime")
else:
    print("not")
# Out:
# not

# %%
even,odd=0,0
num=int(input("enter number\n"))
for i in range(1,num+1):
 if i%2==0:
    even +=i
    continue
odd +=i

print("print even",even)
print("odd",odd)
# Out:
# print even 20
# odd 8

# %%
num=int(input("enter number\n"))
for i in range(2,num+1):
    if num%i==0:
        break
if i==num:
     print("prime",num) 
else:
    print("not",num)
# Out:
# not 6

# %%
num=(input("enter a name"))
rev=num[::-1]
if rev in num:
    print("rev")
else:
    print("no")
# Out:
# rev

# %%
a="sameera"
count=0
for i in a:
 if i in "aeiou":
    count+=1
print(count)
# Out:
# 4

# %%
a=int(input("enter a number"))
for i in range(2,a+1):
      b=i%2==0
      print("print prime")
else:
       print("not")
# Out:
# print prime
# print prime
# print prime
# print prime
# print prime
# not

# %%
def greet(name):
    print("hello",name)
greet("sameera")
greet("yasmeen")
# Out:
# hello sameera
# hello yasmeen

# %%
def greet():
    print("welcome")
greet()
# Out:
# welcome

# %%
def fun(num):
    return num**2
rel=fun(2)
print(rel)
# Out:
# 4

# %%
def larger(a,b):
    if a>b:
        return a
    else:
        return b
print(larger(79,30))
# Out:
# 79

# %%
def factorial(num):
    fact=1
    for i in range(1,num+1):
        fact*=i
    return fact
print(factorial(5))
# Out:
# 120

# %%
def prime(n):
    if n<=1:
        return "not prime"
    for i in range(2,n):
        if n%i==0:
            return " prime"
    return "not"
print(prime(7))
# Out:
# not

# %%
def fact(n):
    if n==1:
      return 1
    else:
       return n*fact(n-1)
num=int(input("enyer a number"))
print(fact(num))
# Out:
# 40320

# %%
num=int(input("enter a number"))
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
age=int(input("enter your age"))
if age>=18:
    print("eligible")
else:
    print("not eligible")
# Out:
# not eligible

# %%
n=100
cal=0
for i in range(1,101):
    cal=cal+i
print(cal)
# Out:
# 5050

# %%
name=(input("enter your name"))
rev=name[::-1]
print(rev)
# Out:
# areemas

# %%
n=int(input("enter a number"))
if n%i==0:
    print("not prime")
else:
    print("prime")
# Out:
# prime

# %%
nums = [10, 5, 80, 25, 60]
largest=nums[0]
for num in nums:
    if num>largest:
        largest=num
print(largest)
# Out:
# 80

# %%
nums = [5, 2, 9, 1, 7]
largest=nums[0]
for i in nums:
    if i>largest:
        largest=i
print(largest)
# Out:
# 9

# %%
def fact(n):
    if n==1:
        return 1
    else:
        return n*fact(n-1)
n=int(input("enter a number"))
print(fact(n))
# Out:
# 362880

# %%
def count_vowels(n):
    count=0
    for i in n:
     if i in "aeiouAEIOU":
        count+=1
        
    return count
print(count_vowels("sameera"))
# Out:
# 4

# %%
def prime(a):
    if a%2==0:
        print("prime")
    else:
        print("not")
prime(4)
# Out:
# prime

# %%
nums = [10, 20, 30, 40, 50]
sum=0
for i in nums:
     sum=sum+i
print(sum)
# Out:
# 150

# %%
nums = [10, 5, 80, 25, 60]
largest=num[0]
for i in nums:
   if i>largest:
        largest=i
print(largest)
# Out:
# 80

# %%
n=5
fact=1
for i in range(1,n+1):
       fact=fact*i
print(fact)
# Out:
# 120

# %%
n="sameera"
rev=""
for i in n:
    rev=i+rev
print(rev)
# Out:
# areemas

# %%
text = "education"
count=0
for i in text:
    if i in "aeiouAEIOU":
     count+=1
print(count)
# Out:
# 5

# %%
text = "sas"
rev=""
for i in text:
    rev=i+rev
if text==rev:
    print("palindrome")
else:
    print("not")
# Out:
# palindrome

# %%
nums = [10, 15, 20, 25, 30, 35]
count=0
for i in nums:
    if i%2==0:
     count+=1
print(count)
# Out:
# 3

# %%
nums = [10, 50, 80, 25, 60]
largest=nums[0]
second=nums[0]
for i in nums:
    if i>largest:
        
    elif i > second and i != largest:
    second = i
    second=largest
    largest=i
print(second)
# Out:
# 50

# %%
nums = [7, 10, 2, 9, 14]
even=0
odd=0
for i in nums:
    if i%2==0:
        even+=1
    else:
        odd+=1
print("even",even) 
print("odd",odd)
# Out:
# even 3
# odd 2

# %%
nums = [10, 20, 30, 40, 50]
sum=0
for i in nums:
    sum=sum+i
print(sum)
# Out:
# 150

# %% [markdown]
# nums = [15, 8, 25, 3, 18]
# max=0
# min=0
# for i in nums

# %%
nums = [15, 8, 25, 3, 18]
maximum=0
min=0
for i in nums:
    if i>maximum:
        maximum=i
        print(maximum)
    if i<min:
        min=i
        print(min)
# Out:
# 15
# 25

# %%
import re
t="python is super easy"
regex=r"ljuhn"
match=re.search(regex,t)
print(match)
# Out:
# None

# %%
def TwoSum(nums,target):
    for i in range(len(nums)):
        for j in range(i+1,len(nums)):
            if nums[i]+nums[j]==target:
               return [i,j]
print(TwoSum( nums=[2,7,11,15], target=9))
# Out:
# [0, 1]

# %%
a=3
b=3
c=5
largest=a
if b>largest:
    largest=b
if c>largest:
    largest=c
print("largest",largest)
# Out:
# largest 5

# %%
n=8
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
n=9
fact=1
for i in range(1,n+1):
    fact=fact*i
print(fact)
# Out:
# 362880

# %%
#count odd
list=[1,2,3,4,5,6,7,8,9]
count=0
for i in list:
    if i%2!=0:
        count+=1
print(count)
# Out:
# 5

# %%
#coutn number greater than 10
lst=[2,4,67,87,35,3,40]
count=0
for i in lst:
    if i>10:
        count+=1
print(count)
# Out:
# 4

# %%
#sum of all num
s=[1,2,3,4,5,6,78,9]
sum=0
for i in s:
    sum=i+sum
print(sum)
# Out:
# 108

# %%
lst=[2,4,67,87,35,3,40]
largest=lst[0]
for i in lst:
    if i >largest:
        largest=i
print(largest)
# Out:
# 87

# %%
lst=[2,4,67,87,35,3,40]
smallest=lst[0]
for i in lst:
    if i<smallest:
        smallest=i
print(smallest)
# Out:
# 2

# %%
#sum of all even numbers
lst = [2, 4, 67, 87, 35, 3, 40]
sum=0
for i in lst:
    if i%2==0:
        sum+=i
print(sum)
# Out:
# 46

# %%
lst = [2, 4, 67, 87, 35, 3, 40]
count=0
for i in lst:
    if i%2==0:
        count+=1
print(count)
# Out:
# 3

# %%
#count consonants
n="banana"
count=0
for i in n:
    if i not in "aeiou":
        count+=1
print(count)
# Out:
# 3

# %%
#reverse
str="sameera"
rev=""
for i in str:
    rev=i+rev
print(rev)
# Out:
# areemas

# %%
#palimdrome
s="level"
rev=""
for i in s:
    rev=i+rev
if s==rev:
     print("palindrome")
else:
     print("not palindrome")
# Out:
# palindrome

# %%
#occurrence of a character
s = "mississippi"
count=0
for i in s:
    if i=="s":
        count+=1
print(count)
# Out:
# 4

# %%
s="banana"
count=0
for i in s:
    if i=="a":
        count+=1
print(count)
# Out:
# 3

# %%
nnum=int(input("enter a number"))
if nnum%2==0:
    print("even")
else:   
    print("odd")
# Out:
# odd

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
if a>b and a>c:
    print(a)
elif b>a and b>c:
    print(b)
else:
    print(c)
# Out:
# 4

# %%
a=int(input("enter a number"))
for i in range(1,11):
    print(a,"x",i,"=",a*i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
sum=int(input("enter a number"))
for i in range(1,sum+1):
    sum=sum+i
print(sum)
# Out:
# 20
